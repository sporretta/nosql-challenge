# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene": 20}

# Use count_documents to display the number of documents in the result
print("Number of documents in result:", establishments.count_documents(query))
# Display the first document in the results using pprint
results=list(establishments.find(query))
pprint(results[0])
# Out:
# Number of documents in result: 41
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': {'$toInt': '$RatingValue'},
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64f23df2f0b3f4bf316bf345'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
import pandas as pd
df=pd.DataFrame(results)

# Display the number of rows in the DataFrame
row_count=len(df)
print(f'The number of rows in the data frame is: {row_count}')
# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# The number of rows in the data frame is: 41
#                         _id   FHRSID  ChangesByServerID  \
# 0  64f23df2f0b3f4bf316bf345   110681                  0
# 1  64f23df3f0b3f4bf316bf6c6   612039                  0
# 2  64f23df3f0b3f4bf316bf9d0   730933                  0
# 3  64f23df3f0b3f4bf316bfbbe   172735                  0
# 4  64f23df3f0b3f4bf316bfbcd   172953                  0
# 5  64f23df3f0b3f4bf316c056c   512854                  0
# 6  64f23df3f0b3f4bf316c078d  1537089                  0
# 7  64f23df4f0b3f4bf316c1cb8   155648                  0
# 8  64f23df4f0b3f4bf316c20fc  1012883                  0
# 9  64f23df5f0b3f4bf316c290e   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
# 6                http://www.southend.gov.uk
# 7                http://www.rochford.gov.uk
# 8              http://www.sevenoaks.gov.uk/
# 9                http://www.basildon.gov.uk
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
#
#                                              geocode RightToReply  \
# 0      {'longitude': 0.27694, 'latitude': 50.769705}
# 1     {'longitude': 1.278721, 'latitude': 51.857536}
# 2      {'longitude': 1.15927, 'latitude': 51.789429}
# 3      {'longitude': 0.10202, 'latitude': 50.770885}
# 4     {'longitude': 0.101446, 'latitude': 50.770724}
# 5     {'longitude': 0.736349, 'latitude': 51.541448}
# 6   {'longitude': 0.7121671, 'latitude': 51.5350065}
# 7     {'longitude': 0.602364, 'latitude': 51.591515}
# 8  {'longitude': 0.146449998021126, 'latitude': 5...
# 9      {'longitude': 0.462307, 'latitude': 51.57005}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {'LocalAuthorityName': {'$regex':'City of London Corporation'},
         'RatingValue': {'$gte': 4}}

# Use count_documents to display the number of documents in the result
print("Number of documents in result:", establishments.count_documents(query))

# Display the first document in the results using pprint
results=list(establishments.find(query))
#pprint(results[0])
# Out:
# Number of documents in result: 0

# %%
# Convert the result to a Pandas DataFrame
df=pd.DataFrame(results)
# Display the number of rows in the DataFrame
print(df.count)
# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# <bound method DataFrame.count of Empty DataFrame
# Columns: []
# Index: []>
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = establishments.find_one({'BusinessName':'Penang Flavours'},{'geocode.latitude':1})['geocode']['latitude']
longitude = establishments.find_one({'BusinessName':'Penang Flavours'},{'geocode.longitude':1})['geocode']['longitude']

query = {'geocode.latitude':{'$gt':latitude-degree_search,'$lt':latitude+degree_search},
         'geocode.longitude':{'$gt':longitude-degree_search,'$lt':longitude+degree_search},
         'RatingValue':5}
sort = [('scores.Hygiene', 1 )]

# Print the results
results=list(establishments.find(query))
pprint(results)
# Out:
# []

# %%
# Convert result to Pandas DataFrame
df=pd.DataFrame(results)
results
# Out:
# []

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

match_query = {'$match': {'scores.Hygiene'==0,}}
group_query = {'$group': {'_id': {"LocalAuthorityName": "$LocalAuthorityName"}}}
sort_values = {'$sort': { 'count': -1 }}
pipeline = [match_query, group_query, sort_values]
# Print the number of documents in the result
results = list(establishments.aggregate(pipeline))
print("Number of rows in result: ", len(results))
# Print the first 10 results
pprint(results[0:10])
# Out:
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# Cell In[64], line 11
#       9 pipeline = [match_query, group_query, sort_values]
#      10 # Print the number of documents in the result
# ---> 11 results = list(establishments.aggregate(pipeline))
#      12 print("Number of rows in result: ", len(results))
#      13 # Print the first 10 results
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pymongo/collection.py:2496, in Collection.aggregate(self, pipeline, session, **kwargs)
#    2423 """Perform an aggregation using the aggregation framework on this
#    2424 collection.
#    2425
#    (...)
#    2493     https://docs.mongodb.com/manual/reference/command/aggregate
#    2494 """
#    2495 with self.__database.client._tmp_session(session, close=False) as s:
# -> 2496     return self._aggregate(_CollectionAggregationCommand,
#    2497                            pipeline,
#    2498                            CommandCursor,
#    2499                            session=s,
#    2500                            explicit_session=session is not None,
#    2501                            **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pymongo/collection.py:2418, in Collection._aggregate(self, aggregation_command, pipeline, cursor_class, session, explicit_session, **kwargs)
#    2412     use_cursor = common.validate_boolean(
#    2413         "useCursor", kwargs.pop("useCursor", True))
#    2415 cmd = aggregation_command(
#    2416     self, cursor_class, pipeline, kwargs, explicit_session,
#    2417     user_fields={'cursor': {'firstBatch': 1}}, use_cursor=use_cursor)
# -> 2418 return self.__database.client._retryable_read(
#    2419     cmd.get_cursor, cmd.get_read_preference(session), session,
#    2420     retryable=not cmd._performs_write)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pymongo/mongo_client.py:1525, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1521         if retrying and not retryable:
#    1522             # A retry is not possible because this server does
#    1523             # not support retryable reads, raise the last error.
#    1524             raise last_error
# -> 1525         return func(session, server, sock_info, secondary_ok)
#    1526 except ServerSelectionTimeoutError:
#    1527     if retrying:
#    1528         # The application may think the write was never attempted
#    1529         # if we raise ServerSelectionTimeoutError on the retry
#    1530         # attempt. Raise the original exception instead.
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pymongo/aggregation.py:137, in _AggregationCommand.get_cursor(self, session, server, sock_info, secondary_ok)
#     134     write_concern = None
#     136 # Run command.
# --> 137 result = sock_info.command(
#     138     self._database.name,
#     139     cmd,
#     140     secondary_ok,
#     141     self.get_read_preference(session),
#     142     self._target.codec_options,
#     143     parse_write_concern_error=True,
#     144     read_concern=read_concern,
#     145     write_concern=write_concern,
#     146     collation=self._collation,
#     147     session=session,
#     148     client=self._database.client,
#     149     user_fields=self._user_fields)
#     151 self._process_result(result, session, server, sock_info, secondary_ok)
#     153 # Extract cursor from result or mock/fake one if necessary.
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pymongo/pool.py:726, in SocketInfo.command(self, dbname, spec, secondary_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     724 # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     725 except BaseException as error:
# --> 726     self._raise_connection_failure(error)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pymongo/pool.py:710, in SocketInfo.command(self, dbname, spec, secondary_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     708     self._raise_if_not_writable(unacknowledged)
#     709 try:
# --> 710     return command(self, dbname, spec, secondary_ok,
#     711                    self.is_mongos, read_preference, codec_options,
#     712                    session, client, check, allowable_errors,
#     713                    self.address, check_keys, listeners,
#     714                    self.max_bson_size, read_concern,
#     715                    parse_write_concern_error=parse_write_concern_error,
#     716                    collation=collation,
#     717                    compression_ctx=self.compression_context,
#     718                    use_op_msg=self.op_msg_enabled,
#     719                    unacknowledged=unacknowledged,
#     720                    user_fields=user_fields,
#     721                    exhaust_allowed=exhaust_allowed)
#     722 except (OperationFailure, NotPrimaryError):
#     723     raise
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pymongo/network.py:118, in command(sock_info, dbname, spec, secondary_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     116 flags = _OpMsg.MORE_TO_COME if unacknowledged else 0
#     117 flags |= _OpMsg.EXHAUST_ALLOWED if exhaust_allowed else 0
# --> 118 request_id, msg, size, max_doc_size = message._op_msg(
#     119     flags, spec, dbname, read_preference, secondary_ok, check_keys,
#     120     codec_options, ctx=compression_ctx)
#     121 # If this is an unacknowledged write then make sure the encoded doc(s)
#     122 # are small enough, otherwise rely on the server to return an error.
#     123 if (unacknowledged and max_bson_size is not None and
#     124         max_doc_size > max_bson_size):
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pymongo/message.py:742, in _op_msg(flags, command, dbname, read_preference, secondary_ok, check_keys, opts, ctx)
#     739     if ctx:
#     740         return _op_msg_compressed(
#     741             flags, command, identifier, docs, check_keys, opts, ctx)
# --> 742     return _op_msg_uncompressed(
#     743         flags, command, identifier, docs, check_keys, opts)
#     744 finally:
#     745     # Add the field back to the command.
#     746     if identifier:
#
# InvalidDocument: cannot encode object: {False}, of type: <class 'set'>

# %%
# Convert the result to a Pandas DataFrame
hygiene_df=pd.DataFrame(results)
# Display the number of rows in the DataFrame
hygiene_df.count
# Display the first 10 rows of the DataFrame
hygiene_df.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
